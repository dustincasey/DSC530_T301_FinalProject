# %%
# Author: Dustin Casey
# Final Project - College Basketball

import pandas as pd

# Importing the data for the regular season.
regular_season = pd.read_csv('regular_season_results.csv')

regular_season.head()
# Out:
#    season  scheduled_date  attendance                 market          name  \
# 0    1996             NaN       11123  University of Alabama  Crimson Tide
# 1    1996             NaN       11123  University of Alabama  Crimson Tide
# 2    1996             NaN       11123  University of Alabama  Crimson Tide
# 3    1996             NaN       11123  University of Alabama  Crimson Tide
# 4    1996             NaN       11123  University of Alabama  Crimson Tide
#
#    team_code                               team_id  \
# 0          8  c2104cdc-c83d-40d2-a3cd-df986e29f5d3
# 1          8  c2104cdc-c83d-40d2-a3cd-df986e29f5d3
# 2          8  c2104cdc-c83d-40d2-a3cd-df986e29f5d3
# 3          8  c2104cdc-c83d-40d2-a3cd-df986e29f5d3
# 4          8  c2104cdc-c83d-40d2-a3cd-df986e29f5d3
#
#                                   alias current_division  points_game  ...  \
# 0  c2104cdc-c83d-40d2-a3cd-df986e29f5d3               D1           72  ...
# ...

# %%
import thinkplot
import thinkstats2
import matplotlib as plt
import statistics

# Histogram of Conference
hist_conf_name = thinkstats2.Hist(regular_season.conf_abrv)
hist_conf_name

plt.style.use('ggplot')
thinkplot.Hist(hist_conf_name)
thinkplot.Config(xlabel='value', ylabel='frequency')

# Replacing categorical Conf_Abrv variable with a numeric value to run summary statistics.
labels = regular_season.conf_abrv.astype('category').cat.categories.tolist()
conf_map_comp = {'conf_abrv': {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}
regular_season.replace(conf_map_comp, inplace=True)

print("Mean: \t",regular_season.conf_abrv.mean())
print("Median: ", regular_season.conf_abrv.median())
print("Mode: \t", statistics.mode(regular_season.conf_abrv))
print("Spread: ", regular_season.conf_abrv.var())
print("Tails: \t", regular_season.conf_abrv.std())
# Out:
# Mean: 	 3.410661692519144
# Median:  3.0
# Mode: 	 1
# Spread:  3.2692181409602226
# Tails: 	 1.8080979345600234

# %%
# Histogram of Oppenent Conference
smaller_data = regular_season[regular_season.opp_conf_abrv.isin(['ACC','BIG12','BIG10','BIGEAST','SEC','PAC12','AAC','A10','CUSA'])]

hist_opp_conf_name = thinkstats2.Hist(smaller_data.opp_conf_abrv)
hist_opp_conf_name

thinkplot.Hist(hist_opp_conf_name)
thinkplot.Config(xlabel='value', ylabel='frequency')

# Replacing categorical Conf_Abrv variable with a numeric value to run summary statistics.
labels = smaller_data.opp_conf_abrv.astype('category').cat.categories.tolist()
opp_conf_map_comp = {'opp_conf_abrv': {k: v for k,v in zip(labels,list(range(1,len(labels)+1)))}}
smaller_data.replace(opp_conf_map_comp, inplace=True)

print("Mean: \t",regular_season.opp_conf_abrv.mean())
print("Median: ", regular_season.opp_conf_abrv.median())
print("Mode: \t", statistics.mode(regular_season.opp_conf_abrv))
print("Spread: ", regular_season.opp_conf_abrv.var())
print("Tails: \t", regular_season.opp_conf_abrv.std())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-ea341f121da0> in <module>
#       5 hist_opp_conf_name
#       6
# ----> 7 thinkplot.Hist(hist_opp_conf_name)
#       8 thinkplot.Config(xlabel='value', ylabel='frequency')
#       9
#
# ~\thinkplot.py in Hist(hist, **options)
#     403     """
#     404     # find the minimum distance between adjacent values
# --> 405     xs, ys = hist.Render()
#     406
#     407     # see if the values support arithmetic
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
# Histogram of Points Scored
hist_points_game = thinkstats2.Hist(regular_season.points_game)
hist_points_game

thinkplot.Hist(hist_points_game)
thinkplot.Config(xlabel='value', ylabel='frequency',xlim=[20, 120])

# Running summary statistics for the variable.
print("Mean: \t",regular_season.points_game.mean())
print("Median: ", regular_season.points_game.median())
print("Mode: \t", statistics.mode(regular_season.points_game))
print("Spread: ", regular_season.points_game.var())
print("Tails: \t", regular_season.points_game.std())
# Out:
# Mean: 	 71.86880031415669
# Median:  71.0
# Mode: 	 71
# Spread:  166.2621556225122
# Tails: 	 12.894268324434396

# %%
# Histogram of Points Allowed
hist_opp_points_game = thinkstats2.Hist(regular_season.opp_points_game)
hist_opp_points_game

thinkplot.Hist(hist_opp_points_game)
thinkplot.Config(xlabel='value', ylabel='frequency', xlim=[20, 120])

# Running summary statistics for the variable.
print("Mean: \t",regular_season.opp_points_game.mean())
print("Median: ", regular_season.opp_points_game.median())
print("Mode: \t", statistics.mode(regular_season.opp_points_game))
print("Spread: ", regular_season.opp_points_game.var())
print("Tails: \t", regular_season.opp_points_game.std())
# Out:
# Mean: 	 67.54205772629099
# Median:  67.0
# Mode: 	 67
# Spread:  157.5748672141671
# Tails: 	 12.552882824840161

# %%
# Histogram of Points Margin
from scipy.stats import skew
import statistics
import matplotlib as plt

plt.style.use('ggplot')
hist_point_margin = plt.pyplot.hist(regular_season.points_margin, bins = 25, rwidth = 0.90, color="#60789b")

# Running summary statistics for the variable.
print("Mean: \t",regular_season.points_margin.mean())
print("Median: ", regular_season.points_margin.median())
print("Mode: \t", statistics.mode(regular_season.points_margin))
print("Spread: ", regular_season.points_margin.var())
print("Tails: \t", regular_season.points_margin.std())
# Out:
# Mean: 	 4.326742587865698
# Median:  4.0
# Mode: 	 3
# Spread:  250.5441237133172
# Tails: 	 15.828585651071835

# %%
# Histogram of Attendance
plt.style.use('ggplot')
hist_point_margin = plt.pyplot.hist(regular_season.attendance, bins = 25, rwidth = 0.90, color="#60789b")

# Running summary statistics for the variable.
print("Mean: \t",regular_season.attendance.mean())
print("Median: ", regular_season.attendance.median())
print("Mode: \t", regular_season.attendance.mode())
print("Spread: ", regular_season.attendance.var())
print("Tails: \t", regular_season.attendance.std())
# Out:
# Mean: 	 11033.24466915374
# Median:  10250.0
# Mode: 	 0     9314
# 1    16300
# dtype: int64
# Spread:  29258717.073108006
# Tails: 	 5409.132746855822

# %%
# Creating two scenarios using the "win" field. Looking at winning teams versus losing teams.
winning_team = regular_season[regular_season.win == True]
losing_team = regular_season[regular_season.win == False]

# Creating PMFs for Points Scored.
winning_pmf = thinkstats2.Pmf(winning_team.points_game,label='winning points scored')
losing_pmf = thinkstats2.Pmf(losing_team.points_game,label='losing points scored')

thinkplot.PrePlot(2)
thinkplot.Pmfs([winning_pmf, losing_pmf])
thinkplot.Show(xlabel='points scored', ylabel = 'probability')

# %%
# Creating CDFs for Attendance.
winning_cdf = thinkstats2.Cdf(winning_team.attendance,label='winning attendance')
losing_cdf = thinkstats2.Cdf(losing_team.attendance,label='losing attendance')

thinkplot.PrePlot(2)
thinkplot.Cdfs([winning_cdf, losing_cdf])
thinkplot.Show(xlabel='attendance', ylabel = 'probability', axis = [0,21000,0,1])

# %%
# Running a normal distribution for point margin.

def MakeNormalPlot(margin):
    mean = margin.mean()
    std = margin.std()
    xs = [-4, 4]
    fxs, fys = thinkstats2.FitLine(xs, inter=mean, slope=std)
    thinkplot.Plot(fxs, fys, color='gray', label='model')
    xs, ys = thinkstats2.NormalProbability(margin)
    thinkplot.Plot(xs, ys, label='points margin')

MakeNormalPlot(regular_season.points_margin)

# I believe a normal distribution fits best for the points margin variable because from the histogram, it appeared to have a
# normal distribution. After running a Normal Probability Plot (NPP), the normal distribution line aligns well with the
# modelled distribution. Although the lines deviate slightly after 2 standard deviations, I believe the 
# fit is still the best possible.

# %%
import numpy as np
import math

# Creating lines of best fit for scatter plots.
denominator_1 = regular_season.points_game.dot(regular_season.points_game)-regular_season.points_game.mean()*regular_season.points_game.sum()
m_1 = (regular_season.points_game.dot(regular_season.points_margin)-regular_season.points_margin.mean()*regular_season.points_game.sum())/denominator_1
b_1 = (regular_season.points_margin.mean()*regular_season.points_game.dot(regular_season.points_game)-regular_season.points_game.mean()*regular_season.points_game.dot(regular_season.points_margin))/denominator_1
y_pred_1 = m_1*regular_season.points_game + b_1

denominator_2 = regular_season.opp_points_game.dot(regular_season.opp_points_game)-regular_season.opp_points_game.mean()*regular_season.opp_points_game.sum()
m_2 = (regular_season.opp_points_game.dot(regular_season.points_margin)-regular_season.points_margin.mean()*regular_season.opp_points_game.sum())/denominator_2
b_2 = (regular_season.points_margin.mean()*regular_season.opp_points_game.dot(regular_season.opp_points_game)-regular_season.opp_points_game.mean()*regular_season.opp_points_game.dot(regular_season.points_margin))/denominator_2
y_pred_2 = m_2*regular_season.opp_points_game + b_2

# Creating scatter plots for points allowed vs point margin
thinkplot.PrePlot(2, cols=2)
thinkplot.Scatter(regular_season.points_game,regular_season.points_margin)
thinkplot.Plot(regular_season.points_game,y_pred_1,color="grey")
thinkplot.Config(xlabel='Points Scored per Game',
              ylabel ='Point Margin')

thinkplot.PrePlot(2)
thinkplot.SubPlot(2)
thinkplot.Scatter(regular_season.opp_points_game,regular_season.points_margin)
thinkplot.Plot(regular_season.opp_points_game,y_pred_2,color="grey")
thinkplot.Show(xlabel='Points Allowed per Game',
              ylabel ='Point Margin')

# Running correlation between the two variables.
def Cov(xs, ys, meanx=None, meany=None):
    xs = np.asarray(xs)
    ys = np.asarray(ys)
    if meanx is None:
        meanx = np.mean(xs)
    if meany is None:
        meany = np.mean(ys)
    cov = np.dot(xs-meanx, ys-meany) / len(xs)
    return cov

def Corr(xs, ys):
    xs = np.asarray(xs)
    ys = np.asarray(ys)
    
    meanx = np.mean(xs)
    varx = np.var(xs)
    meany = np.mean(ys)
    vary = np.var(ys)
    
    corr = Cov(xs, ys, meanx, meany) / math.sqrt(varx * vary)
    return corr

def SpearmanCorr(xs, ys):
    xranks = pd.Series(xs).rank()
    yranks = pd.Series(ys).rank()
    return Corr(xranks, yranks)

print("Correlation tests between Points Scored per Game and Point Margin")
print("Covariance: \t",Cov(regular_season.points_game,regular_season.points_margin))
print("Pearson's Corr: ",Corr(regular_season.points_game,regular_season.points_margin))
print("Spearmans's Corr: ",SpearmanCorr(regular_season.points_game,regular_season.points_margin))

print("\nCorrelation tests between Points Allowed per Game and Point Margin")
print("Covariance: \t",Cov(regular_season.opp_points_game,regular_season.points_margin))
print("Pearson's Corr: ",Corr(regular_season.opp_points_game,regular_season.points_margin))
print("Spearmans's Corr: ",SpearmanCorr(regular_season.opp_points_game,regular_season.points_margin))
# Out:
# Correlation tests between Points Scored per Game and Point Margin
# Covariance: 	 129.6131610832931
# Pearson's Corr:  0.6350659322469839
# Spearmans's Corr:  0.6084699613086582
#
# Correlation tests between Points Allowed per Game and Point Margin
# Covariance: 	 -120.92604324805043
# Pearson's Corr:  -0.6086151861350771
# Spearmans's Corr:  -0.599848727382533

# %%
import random
class HypothesisTest(object):
    def __init__(self, data):
        self.data = data
        self.MakeModel()
        self.actual = self.TestStatistic(data)
        
    def PValue(self, iters=1000):
        self.test_stats = [self.TestStatistic(self.RunModel())
                            for _ in range(iters)]
        
        count = sum(1 for x in self.test_stats if x >= self.actual)
        return count / iters
    
    def TestStatistic(self, data):
        raise UnimplementedMethodException()
        
    def MakeModel(self):
        pass
    def RunModel(self):
        raise UnimplementedMethodException()
        
class DiffMeansPermute(thinkstats2.HypothesisTest):
    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = abs(group1.mean() - group2.mean())
        return test_stat
    def MakeModel(self):
        group1, group2 = self.data
        self.n, self.m = len(group1), len(group2)
        self.pool = np.hstack((group1, group2))
    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data
    
# Creating two datasets, Big 10 conference teams and all others.
big_ten = regular_season[regular_season.conf_name == "Big Ten"]
non_big_ten = regular_season[regular_season.conf_name != "Big Ten"]

# Feeding in data for wins by conference.
data = big_ten.win.values,non_big_ten.win.values
ht = DiffMeansPermute(data)

# Calculating a P-value.
pvalue = ht.PValue()
print(pvalue)
print(ht.actual,ht.MaxTestStat())

ht.PlotCdf()
thinkplot.Config(xlabel='test statistic',
                   ylabel='CDF')
# Out:
# 0.015
# 0.013348443814713229 0.019289491547434423

# %%
import statsmodels.formula.api as smf
 
# Creating new variable "Won" to represent if a team won or lost in a numeric variable.
regular_season['won'] = (regular_season.win==True).astype(int)

# Creating a formula to test if there is a significant relationship between attendance and winning.
formula = 'regular_season.won ~ regular_season.attendance'
model = smf.logit(formula, data=regular_season)
results = model.fit()

print(results.params)
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.672499
#          Iterations 4
# Intercept                    0.545192
# regular_season.attendance   -0.000013
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:     regular_season.won   No. Observations:                50930
# Model:                          Logit   Df Residuals:                    50928
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 28 Feb 2020   Pseudo R-squ.:               0.0008450
# Time:                        15:52:58   Log-Likelihood:                -34250.
# converged:                       True   LL-Null:                       -34279.
# Covariance Type:            nonrobust   LLR p-value:                 2.716e-14
# ...
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ...
